# %%
# !pip install langchain openai chromadb tiktoken pypdf pane
# Out:
# Collecting langchain
#   Using cached langchain-0.0.147-py3-none-any.whl (626 kB)
# Requirement already satisfied: openai in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (0.27.2)
# Collecting chromadb
#   Using cached chromadb-0.3.21-py3-none-any.whl (46 kB)
# Requirement already satisfied: tiktoken in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (0.3.3)
# Collecting pypdf
#   Using cached pypdf-3.8.1-py3-none-any.whl (248 kB)
# Collecting panel
#   Using cached panel-0.14.4-py2.py3-none-any.whl (20.8 MB)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from langchain) (6.0)
# Collecting SQLAlchemy<2,>=1 (from langchain)
#   Using cached SQLAlchemy-1.4.47-cp310-cp310-win_amd64.whl (1.6 MB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from langchain) (3.8.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from langchain) (4.0.2)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain)
#   Using cached dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# Collecting numexpr<3.0.0,>=2.8.4 (from langchain)
#   Using cached numexpr-2.8.4-cp310-cp310-win_amd64.whl (92 kB)
# Requirement already satisfied: numpy<2,>=1 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from langchain) (1.24.2)
# Collecting openapi-schema-pydantic<2.0,>=1.2 (from langchain)
#   Using cached openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
# Requirement already satisfied: pydantic<2,>=1 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from langchain) (1.10.7)
# Requirement already satisfied: requests<3,>=2 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.28.2)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain)
#   Using cached tenacity-8.2.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from langchain) (4.65.0)
# Collecting pandas>=1.3 (from chromadb)
#   Using cached pandas-2.0.0-cp310-cp310-win_amd64.whl (11.2 MB)
# Collecting hnswlib>=0.7 (from chromadb)
#   Using cached hnswlib-0.7.0.tar.gz (33 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting clickhouse-connect>=0.5.7 (from chromadb)
#   Using cached clickhouse_connect-0.5.20-cp310-cp310-win_amd64.whl (221 kB)
# Collecting sentence-transformers>=2.2.2 (from chromadb)
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# Collecting duckdb>=0.7.1 (from chromadb)
#   Using cached duckdb-0.7.1-cp310-cp310-win_amd64.whl (9.5 MB)
# Collecting fastapi>=0.85.1 (from chromadb)
#   Using cached fastapi-0.95.1-py3-none-any.whl (56 kB)
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Using cached uvicorn-0.21.1-py3-none-any.whl (57 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.0.1-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from tiktoken) (2023.3.23)
# Collecting bokeh<2.5.0,>=2.4.0 (from panel)
#   Using cached bokeh-2.4.3-py3-none-any.whl (18.5 MB)
# Collecting param>=1.12.0 (from panel)
#   Using cached param-1.13.0-py2.py3-none-any.whl (87 kB)
# Collecting pyviz-comms>=0.7.4 (from panel)
#   Using cached pyviz_comms-2.2.1-py2.py3-none-any.whl (42 kB)
# Collecting markdown (from panel)
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Collecting pyct>=0.4.4 (from panel)
#   Using cached pyct-0.5.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: bleach in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from panel) (6.0.0)
# Requirement already satisfied: setuptools>=42 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from panel) (63.2.0)
# Requirement already satisfied: typing-extensions in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from panel) (4.5.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (3.1.2)
# Requirement already satisfied: packaging>=16.8 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (23.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (9.5.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (6.3.1)
# Requirement already satisfied: certifi in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from clickhouse-connect>=0.5.7->chromadb) (2022.12.7)
# Requirement already satisfied: urllib3>=1.26 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from clickhouse-connect>=0.5.7->chromadb) (1.26.15)
# Collecting pytz (from clickhouse-connect>=0.5.7->chromadb)
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting zstandard (from clickhouse-connect>=0.5.7->chromadb)
#   Using cached zstandard-0.21.0-cp310-cp310-win_amd64.whl (511 kB)
# Collecting lz4 (from clickhouse-connect>=0.5.7->chromadb)
#   Using cached lz4-4.3.2-cp310-cp310-win_amd64.whl (99 kB)
# Collecting marshmallow<4.0.0,>=3.3.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain)
#   Using cached marshmallow-3.19.0-py3-none-any.whl (49 kB)
# Collecting marshmallow-enum<2.0.0,>=1.5.1 (from dataclasses-json<0.6.0,>=0.5.7->langchain)
#   Using cached marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting typing-inspect>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain)
#   Using cached typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Collecting starlette<0.27.0,>=0.26.1 (from fastapi>=0.85.1->chromadb)
#   Using cached starlette-0.26.1-py3-none-any.whl (66 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.3->chromadb) (2.8.2)
# Collecting tzdata>=2022.1 (from pandas>=1.3->chromadb)
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: six>=1.5 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (3.4)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers>=2.2.2->chromadb)
#   Using cached transformers-4.28.1-py3-none-any.whl (7.0 MB)
# Collecting torch>=1.6.0 (from sentence-transformers>=2.2.2->chromadb)
#   Using cached torch-2.0.0-cp310-cp310-win_amd64.whl (172.3 MB)
# Collecting torchvision (from sentence-transformers>=2.2.2->chromadb)
#   Using cached torchvision-0.15.1-cp310-cp310-win_amd64.whl (1.2 MB)
# Collecting scikit-learn (from sentence-transformers>=2.2.2->chromadb)
#   Using cached scikit_learn-1.2.2-cp310-cp310-win_amd64.whl (8.3 MB)
# Collecting scipy (from sentence-transformers>=2.2.2->chromadb)
#   Using cached scipy-1.10.1-cp310-cp310-win_amd64.whl (42.5 MB)
# Collecting nltk (from sentence-transformers>=2.2.2->chromadb)
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting sentencepiece (from sentence-transformers>=2.2.2->chromadb)
#   Using cached sentencepiece-0.1.98-cp310-cp310-win_amd64.whl (977 kB)
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers>=2.2.2->chromadb)
#   Using cached huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<2,>=1->langchain)
#   Using cached greenlet-2.0.2-cp310-cp310-win_amd64.whl (192 kB)
# Requirement already satisfied: colorama in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.48.0->langchain) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.1.3)
# Requirement already satisfied: h11>=0.8 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.5.0-cp310-cp310-win_amd64.whl (142 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-0.19.0-cp37-abi3-win_amd64.whl (270 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-11.0.2-cp310-cp310-win_amd64.whl (124 kB)
# Requirement already satisfied: webencodings in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: filelock in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb) (3.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=2.9->bokeh<2.5.0,>=2.4.0->panel) (2.1.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from starlette<0.27.0,>=0.26.1->fastapi>=0.85.1->chromadb) (3.6.2)
# Collecting sympy (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb)
#   Using cached sympy-1.11.1-py3-none-any.whl (6.5 MB)
# Collecting networkx (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb)
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb)
#   Using cached tokenizers-0.13.3-cp310-cp310-win_amd64.whl (3.5 MB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Collecting joblib (from nltk->sentence-transformers>=2.2.2->chromadb)
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->sentence-transformers>=2.2.2->chromadb)
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aaron\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.27.0,>=0.26.1->fastapi>=0.85.1->chromadb) (1.3.0)
# Collecting mpmath>=0.19 (from sympy->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Building wheels for collected packages: hnswlib
#   Building wheel for hnswlib (pyproject.toml): started
#   Building wheel for hnswlib (pyproject.toml): finished with status 'done'
#   Created wheel for hnswlib: filename=hnswlib-0.7.0-cp310-cp310-win_amd64.whl size=140826 sha256=fe50412a42375f95e2a9d1bbf3ce2f8dcd96335b84bc65861c1ec347126ed2a4
#   Stored in directory: c:\users\aaron\appdata\local\pip\cache\wheels\8a\ae\ec\235a682e0041fbaeee389843670581ec6c66872db856dfa9a4
# Successfully built hnswlib
# Installing collected packages: tokenizers, sentencepiece, pytz, mpmath, monotonic, duckdb, zstandard, websockets, tzdata, typing-inspect, threadpoolctl, tenacity, sympy, scipy, pypdf, param, numexpr, networkx, marshmallow, markdown, lz4, joblib, httptools, hnswlib, greenlet, backoff, watchfiles, uvicorn, torch, starlette, SQLAlchemy, scikit-learn, pyviz-comms, pyct, posthog, pandas, openapi-schema-pydantic, nltk, marshmallow-enum, huggingface-hub, clickhouse-connect, bokeh, transformers, torchvision, panel, fastapi, dataclasses-json, sentence-transformers, langchain, chromadb
# Successfully installed SQLAlchemy-1.4.47 backoff-2.2.1 bokeh-2.4.3 chromadb-0.3.21 clickhouse-connect-0.5.20 dataclasses-json-0.5.7 duckdb-0.7.1 fastapi-0.95.1 greenlet-2.0.2 hnswlib-0.7.0 httptools-0.5.0 huggingface-hub-0.13.4 joblib-1.2.0 langchain-0.0.147 lz4-4.3.2 markdown-3.4.3 marshmallow-3.19.0 marshmallow-enum-1.5.1 monotonic-1.6 mpmath-1.3.0 networkx-3.1 nltk-3.8.1 numexpr-2.8.4 openapi-schema-pydantic-1.2.4 pandas-2.0.0 panel-0.14.4 param-1.13.0 posthog-3.0.1 pyct-0.5.0 pypdf-3.8.1 pytz-2023.3 pyviz-comms-2.2.1 scikit-learn-1.2.2 scipy-1.10.1 sentence-transformers-2.2.2 sentencepiece-0.1.98 starlette-0.26.1 sympy-1.11.1 tenacity-8.2.2 threadpoolctl-3.1.0 tokenizers-0.13.3 torch-2.0.0 torchvision-0.15.1 transformers-4.28.1 typing-inspect-0.8.0 tzdata-2023.3 uvicorn-0.21.1 watchfiles-0.19.0 websockets-11.0.2 zstandard-0.21.0

# %%
import os 
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI
from langchain.document_loaders import TextLoader
from langchain.document_loaders import PyPDFLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
import panel as pn

# %%
pn.extension('texteditor', template="bootstrap", sizing_mode='stretch_width')
pn.state.template.param.update(
    main_max_width="690px",
    header_background="#F08080",
)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
file_input = pn.widgets.FileInput(width=300)

openaikey = pn.widgets.PasswordInput(
    value="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", placeholder="Insert your openai api key here", width=300
)
prompt = pn.widgets.TextEditor(
    value="", placeholder="How do you become a good programmer?", height=160, toolbar=False
)
search_button = pn.widgets.Button(name="Search!")

select_k = pn.widgets.IntSlider(
    name="Number of relevant chunks", start=1, end=10, step=1, value=2
)
select_chain_type = pn.widgets.RadioButtonGroup(
    name='Chain type', 
    options=['stuff', 'map_reduce', "refine", "map_rerank"]
)

legend = pn.pane.Markdown("""
**Chain types:**

- `stuff`: Parse the entire document at one go. (for smaller documents)
- `map_reduce`: Split the document into smaller chunks in parallel. (faster processing but less detailed answer)
- `refine`: Split the document into smaller chunks subsequently. (slower processing but more detailed answer)
- `map_rerank`: Split the document and into individual chunks. (for simple questions)
""")

widgets = pn.Row(
    pn.Column(prompt, search_button, margin=5),
    pn.Card(
        "Chain type:",
        pn.Column(select_chain_type, select_k),
        title="Advanced settings", margin=10
    ), 
    pn.Column(legend)
)

# %%
def qa(file, query, chain_type, k):
    # load document, ifelse file/link ending with txt, pdf statement here
    loader = PyPDFLoader(file)
    documents = loader.load()
    # split the documents into chunks
    text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
    texts = text_splitter.split_documents(documents)
    # select which embeddings we want to use
    embeddings = OpenAIEmbeddings()
    # create the vectorestore to use as the index
    db = Chroma.from_documents(texts, embeddings)
    # expose this index in a retriever interface
    retriever = db.as_retriever(search_type="similarity", search_kwargs={"k": k})
    # create a chain to answer questions 
    qa = RetrievalQA.from_chain_type(
        llm=OpenAI(), chain_type=chain_type, retriever=retriever, return_source_documents=True)
    result = qa({"query": query})
    print(result['result'])
    return result

# %%
convos = []  # store all panel objects in a list

def qa_result(_):
    os.environ["OPENAI_API_KEY"] = openaikey.value
    
    # save pdf file to a temp file 
    if file_input.value is not None:
        file_input.save("/.cache/temp.pdf")
    
        prompt_text = prompt.value
        if prompt_text:
            result = qa(file="/.cache/temp.pdf", query=prompt_text, chain_type=select_chain_type.value, k=select_k.value)
            convos.extend([
                pn.Row(
                    pn.panel("\U0001F60A", width=10),
                    prompt_text,
                    width=600
                ),
                pn.Row(
                    pn.panel("\U0001F916", width=10),
                    pn.Column(
                        result["result"],
                        "Relevant source text:",
                        pn.pane.Markdown('\n--------------------------------------------------------------------\n'.join(doc.page_content for doc in result["source_documents"]))
                    )
                )
            ])
            #return convos
    return pn.Column(*convos, margin=15, width=575, min_height=400)

# %%
qa_interactive = pn.panel(
    pn.bind(qa_result, run_button),
    loading_indicator=True,
)

# %%
output = pn.WidgetBox('*Output will show up here:*', qa_interactive, width=630, scroll=True)

# %%
# layout
pn.Column(
    pn.pane.Markdown("""
    ## \U0001F60A! Question Answering with your PDF file
    
    1) Upload a PDF. 2) Enter OpenAI API key. This costs $. Set up billing at [OpenAI](https://platform.openai.com/account). 3) Type a question and click "Run".
    
    """),
    pn.Row(file_input,pn.pane.HTML("OpenAI API Key: ", width=110, align="end"), openaikey),
    output,
    widgets

).servable()
# Out:
# Column(sizing_mode='stretch_width')
#     [0] Markdown(str, sizing_mode='stretch_width')
#     [1] Row(sizing_mode='stretch_width')
#         [0] FileInput(width=300)
#         [1] HTML(str, align='end', width=110)
#         [2] PasswordInput(placeholder='Insert your o..., value='sk-AxQw5rfYepVB7zo9MxMlT3..., value_input='sk-AxQw5rfYepVB7zo9MxMlT3..., width=300)
#     [2] WidgetBox(scroll=True, width=630)
#         [0] Markdown(str, sizing_mode='stretch_width')
#         [1] ParamFunction(function, _pane=Column, loading_indicator=True, sizing_mode='stretch_width')
#     [3] Row(sizing_mode='stretch_width')
#         [0] Column(margin=5, sizing_mode='stretch_width')
#             [0] TextEditor(height=160, placeholder='How do you become a..., sizing_mode='stretch_width', toolbar=False)
#             [1] Button(name='Search!', sizing_mode='stretch_width')
#         [1] Card(margin=10, sizing_mode='stretch_width', title='Advanced settings')
#             [0] Markdown(str, sizing_mode='stretch_width')
#             [1] Column(sizing_mode='stretch_width')
#                 [0] RadioButtonGroup(name='Chain type', options=['stuff', 'map_reduce', ...], sizing_mode='stretch_width', value='stuff')
#                 [1] IntSlider(end=5, name='Number of relevant c..., sizing_mode='stretch_width', start=1, value=2)
#         [2] Column(sizing_mode='stretch_width')
#             [0] Markdown(str, sizing_mode='stretch_width')
